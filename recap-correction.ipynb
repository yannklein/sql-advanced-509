# %% [markdown]
# # Reboot - SQL Advanced
#
# Tonight, we will use a Blog SQLite database:

# %%
# !tree
# Out:
# .
# ├── data
# │   ├── blog.sqlite
# │   ├── ecommerce.sqlite
# │   ├── exploitable_db.sqlite
# │   └── students.sqlite
# ├── exploit.py
# ├── recap-correction.ipynb
# └── recap.ipynb
#
# 1 directory, 7 files

# %% [markdown]
# ## 1. Schema ERD
#
# ❓ Open the `data/blog.sqlite` in DBeaver, explore the schema and draw it on [kitt.lewagon.com/db](https://kitt.lewagon.com/db).

# %% [markdown]
# _TODO: Double click this cell and **paste** a screenshot of the schema for future reference_.

# %% [markdown]
# ---
# ## 2. Most liked posts
#
# Complete the code to get **the 3 most liked posts**:

# %%
import sqlite3

conn = sqlite3.connect("data/blog.sqlite")
c = conn.cursor()

# TODO: write the query
query = """
    SELECT posts.title, posts.content, COUNT(posts.id)
    FROM posts
    JOIN likes ON likes.post_id = posts.id
    GROUP BY posts.id
    ORDER BY COUNT(posts.id) DESC
    LIMIT 3
"""

# TODO: Execute the query
c.execute(query)
rows = c.fetchall()

# TODO: Fetch and print the results
rows
# Out:
# [('Half imagine another.',
#   'Nice career practice image. Modern son per share painting successful on.',
#   84),
#  ('Side foot leader popular.',
#   'Relate parent run public choice allow. Establish single far Congress impact course offer.',
#   82),
#  ('Area paper whatever mean.',
#   'Space whose often computer. Yard account stuff section write store somebody. Coach none blue skin finish any.',
#   81)]

# %% [markdown]
# ---
#
# ### Pretty Print using _pandas_
#
# The readbility of our `print()` statements are not so good.
#
# Next week, we will introduce [pandas](https://pandas.pydata.org/) which will largely improve the UX of our Data Exploration in Notebooks.
#
# Execute the following cell:

# %%
import pandas as pd

def execute_and_print(query):
    conn = sqlite3.connect('data/blog.sqlite')
    c = conn.cursor()
    rows = c.execute(query)
    return pd.DataFrame(rows.fetchall(), columns=[header[0] for header in rows.description])

execute_and_print(query)
# Out:
#   first_name last_name  COUNT(likes.id)
# 0    Michael     Allen              236
# 1      Donna   Ramirez              233
# 2    Barbara     Hurst              227

# %% [markdown]
# Then try again the previous `query`, delegating the job of fetching results + displaying them to the `execute_and_print` function and `pandas`:

# %%
pd.read_sql_query(query, conn)
# Out:
#                        title  \
# 0      Half imagine another.
# 1  Side foot leader popular.
# 2  Area paper whatever mean.
#
#                                              content  COUNT(posts.id)
# 0  Nice career practice image. Modern son per sha...               84
# 1  Relate parent run public choice allow. Establi...               82
# 2  Space whose often computer. Yard account stuff...               81

# %% [markdown]
# ---
# ## 3. Find the three users who 'liked' the most

# %%
query = """
    SELECT users.first_name, users.last_name, COUNT(likes.id)
    FROM users
    JOIN likes ON users.id = likes.user_id
    GROUP BY users.id
    ORDER BY COUNT(likes.id) DESC
    LIMIT 3
"""

pd.read_sql_query(query, conn)
# Out:
#   first_name last_name  COUNT(likes.id)
# 0    Michael     Allen              236
# 1      Donna   Ramirez              233
# 2    Barbara     Hurst              227

# %% [markdown]
# ---
# ## 4. Find the most liked author

# %%
pd.read_sql_query("""
    SELECT users.first_name, users.last_name, posts.title, COUNT(likes.id) likes_count
    FROM users
    JOIN likes ON posts.id = likes.post_id
    JOIN posts ON users.id = posts.user_id
    GROUP BY users.id
    ORDER BY likes_count DESC
    LIMIT 1
""", conn)
# Out:
#   first_name last_name                                      title  likes_count
# 0     Teresa     Moore  Still relationship rock surface son wait.          647

# %% [markdown]
# ---
# ## 5. Who are the authors of the 3 most liked posts?

# %%
pd.read_sql_query("""
    SELECT users.first_name, users.last_name, posts.title, COUNT(likes.id) likes_count
    FROM users
    JOIN posts ON users.id = posts.user_id
    JOIN likes ON posts.id = likes.post_id
    GROUP BY posts.id
    ORDER BY likes_count DESC
    LIMIT 3
""", conn)
# Out:
#   first_name last_name                      title  likes_count
# 0    Melissa     Henry      Half imagine another.           84
# 1    Cynthia   Raymond  Side foot leader popular.           82
# 2  Alexander      Cook  Area paper whatever mean.           81

# %% [markdown]
# ---
# ## 6. How many people liked at least one post?

# %%
pd.read_sql_query("""
    WITH likes_info AS (
    SELECT *, COUNT(likes.id) likes_count
    FROM users
    JOIN likes ON users.id = likes.user_id
    GROUP BY users.id
    HAVING COUNT(likes.id) >= 1
    )
    
    SELECT COUNT(likes_count)
    FROM likes_info
""", conn)
# Out:
#    COUNT(likes_count)
# 0                  49

# %% [markdown]
# ---
# ## 7. Compute the cumulative number of likes per day

# %%
pd.read_sql_query("""
    SELECT
        COUNT(likes.id),
        likes.created_at,
        SUM(COUNT(likes.id)) OVER (
            ORDER BY likes.created_at
        ) as cumulative_like_per_day
    FROM likes
    GROUP BY likes.created_at
""", conn)
# Out:
#      COUNT(likes.id)  created_at  cumulative_like_per_day
# 0                 24  2019-01-01                       24
# 1                 34  2019-01-02                       58
# 2                 40  2019-01-03                       98
# 3                 36  2019-01-04                      134
# 4                 27  2019-01-05                      161
# ..               ...         ...                      ...
# 331               35  2019-12-24                     9882
# 332               33  2019-12-25                     9915
# 333               32  2019-12-26                     9947
# 334               23  2019-12-27                     9970
# 335               30  2019-12-28                    10000
#
# [336 rows x 3 columns]

# %% [markdown]
# ---
# ## 8. (Optional) Who's the biggest fan of each author?
#
# The biggest fan of an author is defined as the user who liked the most the author's posts.
# <br><br>
# <details>
#     <summary>💡 Click for Hint</summary>
#     You might need to use <code>WITH</code>
# </details>

# %%
pd.read_sql_query("""
    SELECT 
        (authors.first_name || ' ' || authors.last_name) AS author_name,
        posts.title,
        likes.user_id AS liker_id,
        COUNT(likes.user_id) likes_count
    FROM users AS authors
    JOIN posts ON authors.id = posts.user_id
    JOIN likes ON posts.id = likes.post_id
    GROUP BY authors.id, likes.user_id
    ORDER BY likes_count DESC
""", conn)
# Out:
#           author_name                                              title  \
# 0        Teresa Moore                        Direction arm practice for.
# 1     Cynthia Raymond                Study best whom party indeed those.
# 2         James Jones                    Policy environment carry offer.
# 3     Cynthia Raymond                  A cold drop test build word yeah.
# 4     Jennifer Mendez  Never specific would every knowledge exactly m...
# ...               ...                                                ...
# 1189    Melissa Henry                              Half imagine another.
# 1190    Melissa Henry                              Half imagine another.
# 1191    Melissa Henry                              Half imagine another.
# 1192    Melissa Henry                              Half imagine another.
# 1193    Melissa Henry                              Half imagine another.
#
#       liker_id  likes_count
# 0            9           24
# 1           45           24
# 2           44           24
# 3           15           23
# 4           29           21
# ...        ...          ...
# 1189        42            1
# 1190        43            1
# 1191        44            1
# 1192        48            1
# 1193        49            1
#
# [1194 rows x 4 columns]

# %%
pd.read_sql_query("""
    WITH author_likers AS (
        SELECT 
            (authors.first_name || ' ' || authors.last_name) AS author_name,
            posts.title,
            likes.user_id AS liker_id,
            COUNT(likes.user_id) likes_count
        FROM users AS authors
        JOIN posts ON authors.id = posts.user_id
        JOIN likes ON posts.id = likes.post_id
        GROUP BY authors.id, likes.user_id
        ORDER BY likes_count DESC
    )
    SELECT 
        author_likers.author_name,
        author_likers.title,
        (users.first_name || ' ' || users.last_name) AS best_liker_name,
        MAX(author_likers.likes_count) as likes
    FROM author_likers
    JOIN users ON users.id = author_likers.liker_id
    GROUP BY author_likers.author_name
""", conn)
# Out:
#         author_name                                              title  \
# 0    Alexander Cook     Best detail hair quality out through together.
# 1    Brenda Griffin                         Help give in real instead.
# 2    Brett Johnston           Nothing article stand school cup choice.
# 3   Brittany Miller                            Charge pattern soldier.
# 4   Cynthia Raymond                Study best whom party indeed those.
# 5        David Boyd         Bed focus tell floor special rate husband.
# 6       Donna Smith         Pattern with government discussion worker.
# 7      Eric Carroll               National writer senior create focus.
# 8        Erin Smith    Member way sort hair democratic condition must.
# 9        Grace Kerr                        Financial less attack with.
# 10      James Jones                    Policy environment carry offer.
# 11  Jennifer Mendez  Never specific would every knowledge exactly m...
# 12    Juan Lawrence                        Hundred majority a usually.
# 13      Lisa Palmer          Note measure edge security allow exactly.
# 14  Madeline Porter                      Information side grow almost.
# 15     Mary Sanders                          Drop after current month.
# 16    Melissa Henry                              Half imagine another.
# 17   Melissa Nelson    Design purpose indicate threat character ready.
# 18     Pamela Mason  In democratic assume she specific blue poor pl...
# 19       Ricky Cook              His sense hot level while I decision.
# 20    Robert Dorsey        Send per study cup before wrong talk learn.
# 21      Susan Villa  Peace expert fall coach share election sometimes.
# 22     Teresa Moore                        Direction arm practice for.
# 23  Timothy Johnson                  Market others agreement act item.
# 24     Tyler Wilson              Kitchen into assume Republican thank.
#
#     best_liker_name  likes
# 0     Jeremiah Ruiz     20
# 1     Michael Allen     12
# 2    Tristan Kelley     19
# 3     Barbara Hurst     16
# 4       Donald Gray     24
# 5     Barbara Hurst     18
# 6       Karen Brown     20
# 7       James Payne     18
# 8       Lisa Norris      7
# 9     Ashley Brooks     19
# 10  Hayley Williams     24
# 11      Kaylee Ball     21
# 12      David Evans     12
# 13    Ashley Brooks     17
# 14    Donna Ramirez     12
# 15   Scott Thompson     18
# 16     Amber Nguyen      4
# 17     Sandra Davis     20
# 18   Jessica Walker      6
# 19     Michael Pugh     12
# 20       Bruce Chen     17
# 21    Anthony Wiley      6
# 22    Maria Mccarty     24
# 23    Donna Ramirez      3
# 24   Scott Thompson      8
